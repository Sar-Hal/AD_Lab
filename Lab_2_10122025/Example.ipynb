# %%
import pandas as pd
import numpy as np
d = [(101,4),(102,5),(103,3)]
df = pd.DataFrame(d, columns=['Roll','Score'])
print(df)
# Out:
#    Roll  Score
# 0   101      4
# 1   102      5
# 2   103      3

# %% [markdown]
# <font size='5' color='red'>Missing Heading Handling</font>

# %%
df = pd.read_csv('data2.csv', names = ["Roll","Score"])
df.head()
# Out:
#       Roll  Score
# 0  2005011    4.0
# 1  2005058    5.0
# 2  2005076    3.0
# 3  2005119    4.0
# 4  2005150    5.0
